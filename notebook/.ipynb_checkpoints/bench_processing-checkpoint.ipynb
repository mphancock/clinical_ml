# %%
import pandas as pd 
import os 

csv_path = '/legodata/zhaoj/cvd_risk_time2/src/ML/csv' 

df_feat = pd.read_csv(os.path.join(csv_path, 'xgb_feat_TrueTruemd8lr0.1ss1.0spw5_test_1'))
df_pred = pd.read_csv(os.path.join(csv_path, 'xgb_pred_TrueTruemd8lr0.1ss1.0spw5_test_1'))

# %%
df_feat
# Out:
#       Unnamed: 0                             RANK_0  IMPORTANCE_0  \
# 0              0                           med_1191      0.014925
# 1              1                    AGE_AT_BASELINE      0.014925
# 2              2                           med_4603      0.013381
# 3              3               DURATION_BF_BASELINE      0.012867
# 4              4                          med_32968      0.010808
# 5              5                           med_4917      0.009779
# 6              6                       MAX_SYSTOLIC      0.007720
# 7              7              ('Gluc', 'MAX_VALUE')      0.007720
# 8              8                            phe_418      0.007205
# 9              9                            SMOKING      0.006691
# 10            10                            MIN_BMI      0.006176
# 11            11                    missing_bp_True      0.005661
# 12            12                          phe_401.1      0.005147
# ...

# %%
test = pd.DataFrame({'A':[1,1], 'B': [2,2], 'C': [3,3]})
test2 = pd.DataFrame()

# %%
pd.concat([test, test2], axis=1)
# Out:
#    A  B  C
# 0  1  2  3
# 1  1  2  3

# %%
test3 = pd.DataFrame().reindex_like(test).iloc[0:0]

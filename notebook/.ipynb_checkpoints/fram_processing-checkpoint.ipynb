# %% [raw]
# import pandas as pd
# import os
#
# data_path = '/legodata/zhaoj/cvd_risk_time2/src/ML/'
#
# df_grid_cv = pd.read_csv(os.path.join(data_path, 'grid_search_cv.csv'))

# %%
df_grid_cv.sort_values(by=['mean_test_score'], ascending=False)
# Out:
#     Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 5            5    1198.731012         2.437190         0.719712
# 4            4    1313.112020         2.477173         0.717257
# 15          15    1404.213186         2.301233         0.717065
# 17          17    1185.142937         2.575174         0.716978
# 16          16    1325.935479         2.355353         0.716613
# 18          18    2074.754058         2.403721         0.715596
# 19          19    1925.361159         2.629680         0.715139
# 1            1     669.083872         2.583164         0.714933
# 20          20    1818.593207         2.700071         0.714928
# 0            0     733.053466         2.314140         0.714820
# 3            3    1441.606572         2.651846         0.714634
# 2            2     592.519909         2.207601         0.714533
# 22          22    2672.506045         2.790805         0.707452
# 33          33    2831.560930         3.104225         0.706454
# ...

# %%
df_grid_cv.sort_values(by=['mean_train_score'], ascending=False)
# Out:
#     Unnamed: 0  mean_fit_time  mean_score_time  mean_test_score  \
# 11          11    2451.833962         2.997225         0.680916
# 10          10    2657.187735         2.828165         0.680681
# 9            9    2815.745907         2.904958         0.678173
# 23          23    2545.966829         2.938314         0.704317
# 22          22    2672.506045         2.790805         0.707452
# 8            8    1863.952498         2.659267         0.702235
# 7            7    1989.211031         2.545482         0.699921
# 21          21    2773.671543         2.796770         0.706132
# 6            6    2146.192024         2.708287         0.695999
# 20          20    1818.593207         2.700071         0.714928
# 19          19    1925.361159         2.629680         0.715139
# 18          18    2074.754058         2.403721         0.715596
# 5            5    1198.731012         2.437190         0.719712
# 4            4    1313.112020         2.477173         0.717257
# ...

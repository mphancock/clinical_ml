# %%
import pandas as pd 

data_path = '/legodata/zhaoj/cvd_risk_time2/data_1_8/for_framingham/processed/merged_fr_results_remove_age.csv'
df = pd.read_csv(data_path)

# %%
print(len(df))
df
# Out:
# 170658
#               GRID GENDER Original_RACE   DOB FIRST_CVD_DATE  \
# 0       R290108078      M             W  1949     2008-06-01
# 1       R240692237      M             W  1932     2017-03-07
# 2       R277435259      F             W  1951     2014-02-02
# 3       R269880338      F             W  1956     2017-04-04
# 4       R272530184      M             W  1965     2016-09-07
# 5       R220222075      F             U  1941     2014-03-23
# 6       R237127627      F             W  1940     1999-08-24
# 7       R209142093      M             W  1949     2006-08-16
# 8       R244074500      F             B  1946     2004-06-11
# 9       R247495396      F             W  1960     2013-05-27
# 10      R265825077      M             B  1966     2005-10-11
# 11      R238362733      F             W  1953     2014-11-26
# 12      R272583636      M             W  1950     2016-05-26
# 13      R230078332      F             W  1960     2012-08-08
# ...

# %%
import seaborn as sns 
import matplotlib.pyplot as plt 

sns.boxplot(y='frs', data=df)
plt.show()
